# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# - log transformation
# - exponential transformation
# - reciprocal transformation
# - sqrt transformation

# %%
exp_data=np.random.exponential(size=1000)
exp_data#this willl give 1000 random samples
#if u plot the distribution 
#it follows exponential
plt.hist(exp_data,bins=20)
# Out:
# (array([308., 187., 145.,  97.,  83.,  55.,  40.,  20.,  17.,  18.,  10.,
#           7.,   3.,   5.,   1.,   1.,   1.,   0.,   1.,   1.]),
#  array([2.55442860e-03, 3.41955212e-01, 6.81355995e-01, 1.02075678e+00,
#         1.36015756e+00, 1.69955835e+00, 2.03895913e+00, 2.37835991e+00,
#         2.71776070e+00, 3.05716148e+00, 3.39656226e+00, 3.73596305e+00,
#         4.07536383e+00, 4.41476461e+00, 4.75416540e+00, 5.09356618e+00,
#         5.43296696e+00, 5.77236775e+00, 6.11176853e+00, 6.45116931e+00,
#         6.79057009e+00]),
#  <BarContainer object of 20 artists>)

# %%
nor_data=np.random.normal(size=1000)
plt.hist(nor_data,bins=20)
# Out:
# (array([  2.,   4.,   7.,  21.,  34.,  49.,  66.,  93., 106., 127., 116.,
#          97., 109.,  79.,  44.,  19.,  13.,   8.,   4.,   2.]),
#  array([-3.14613041, -2.83299862, -2.51986683, -2.20673505, -1.89360326,
#         -1.58047148, -1.26733969, -0.95420791, -0.64107612, -0.32794434,
#         -0.01481255,  0.29831923,  0.61145102,  0.9245828 ,  1.23771459,
#          1.55084637,  1.86397816,  2.17710994,  2.49024173,  2.80337351,
#          3.1165053 ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# **main goal is convert exponential data to noamal data**

# %% [markdown]
# **log transformation**

# %%
x=10
np.log(10)
# Out:
# 2.302585092994046

# %%
log_data=np.log(exp_data)
plt.subplot(2,1,1).hist(exp_data)
plt.subplot(2,1,2).hist(log_data)
# Out:
# (array([  2.,   9.,  15.,  32.,  66., 145., 209., 273., 203.,  46.]),
#  array([-5.96992672, -5.18138056, -4.3928344 , -3.60428823, -2.81574207,
#         -2.02719591, -1.23864975, -0.45010359,  0.33844258,  1.12698874,
#          1.9155349 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(exp_data)
plt.hist(log_data)
# Out:
# (array([  2.,   9.,  15.,  32.,  66., 145., 209., 273., 203.,  46.]),
#  array([-5.96992672, -5.18138056, -4.3928344 , -3.60428823, -2.81574207,
#         -2.02719591, -1.23864975, -0.45010359,  0.33844258,  1.12698874,
#          1.9155349 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# **sqrt transformation**

# %%
exp_data=np.random.exponential(size=100)
nor_data=np.random.normal(size=100)
plt.hist(exp_data)
plt.hist(nor_data)
# Out:
# (array([ 3.,  2., 11.,  9., 15., 19., 17., 11.,  7.,  6.]),
#  array([-2.0198756 , -1.60445549, -1.18903538, -0.77361528, -0.35819517,
#          0.05722493,  0.47264504,  0.88806514,  1.30348525,  1.71890536,
#          2.13432546]),
#  <BarContainer object of 10 artists>)

# %%
sqrt_data=np.sqrt(exp_data)

# %%
plt.hist(exp_data)
plt.hist(sqrt_data)
# Out:
# (array([11., 16., 23., 20.,  9., 10.,  7.,  0.,  2.,  2.]),
#  array([0.04582928, 0.27729544, 0.5087616 , 0.74022776, 0.97169392,
#         1.20316007, 1.43462623, 1.66609239, 1.89755855, 2.12902471,
#         2.36049087]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# **reciprocal transformation**

# %%
exp_data=np.random.exponential(size=100)
nor_data=np.random.normal(size=100)

# %%
plt.hist(exp_data)
# Out:
# (array([38., 25., 12., 12.,  4.,  6.,  1.,  0.,  1.,  1.]),
#  array([1.63568920e-04, 4.27796019e-01, 8.55428468e-01, 1.28306092e+00,
#         1.71069337e+00, 2.13832582e+00, 2.56595827e+00, 2.99359072e+00,
#         3.42122317e+00, 3.84885562e+00, 4.27648807e+00]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(nor_data)
# Out:
# (array([ 2.,  5.,  5., 19., 20., 18., 12., 10.,  7.,  2.]),
#  array([-2.64320506, -2.10687847, -1.57055188, -1.03422528, -0.49789869,
#          0.0384279 ,  0.5747545 ,  1.11108109,  1.64740768,  2.18373428,
#          2.72006087]),
#  <BarContainer object of 10 artists>)

# %%
rec_data=np.exp(exp_data)
plt.hist(exp_data)
plt.hist(rec_data)
plt.show()

# %%
visa_df=pd.read_csv(r"C:\Users\kisho\Documents\data set\Visadataset.csv")
cat=visa_df.select_dtypes(include=object).columns
num=visa_df.select_dtypes(exclude=object).columns
cat,num
# Out:
# (Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#         'requires_job_training', 'region_of_employment', 'unit_of_wage',
#         'full_time_position', 'case_status'],
#        dtype='object'),
#  Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object'))

# %%
#how to read a column
visa_df['prevailing_wage']

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()
ss.fit_transform(visa_df['prevailing_wage'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 ss=StandardScaler()
# ----> 2 ss.fit_transform(visa_df['prevailing_wage'])
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:878, in TransformerMixin.fit_transform(self, X, y, **fit_params)
# ...

# %%
ValueError: Expected 2D array, got 1D array instead:
array=[   592.2029  83425.65   122996.86   ... 146298.85    86154.77
  70876.91  ].
Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
#i want to extract value as list so used .values()
visa_df['prevailing_wage'].values
# Out:
# array([   592.2029,  83425.65  , 122996.86  , ..., 146298.85  ,
#         86154.77  ,  70876.91  ])

# %%
np.array([1,2,3,4,])
# Out:
# array([1, 2, 3, 4])

# %%
np.ndim(np.array([1,2,3,4]))
# Out:
# 1

# %%
np.ndim(np.array([[1,2,3,4]]))
# Out:
# 2

# %%
visa_df['prevailing_wage'].values.reshape(-1,1)
# Out:
# array([[   592.2029],
#        [ 83425.65  ],
#        [122996.86  ],
#        ...,
#        [146298.85  ],
#        [ 86154.77  ],
#        [ 70876.91  ]])

# %%
np.ndim(visa_df['prevailing_wage'].values.reshape(-1,1))
# Out:
# 2

# %% [markdown]
# **power transformer**

# %%
#sklearn
#prprocessing

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()

# %%
transform_wage=pt.fit_transform(visa_df[['prevailing_wage']])
transform_wage
# Out:
# array([[-1.93915141],
#        [ 0.34503309],
#        [ 0.91555926],
#        ...,
#        [ 1.21170443],
#        [ 0.38794165],
#        [ 0.13879466]])

# %%
plt.figure(figsize=(14,4))
plt.subplot(1,2,1).hist(visa_df[['prevailing_wage']],bins=30)
plt.subplot(1,2,2).hist(transform_wage,bins=30)
plt.show()

# %%
- yeo_johnson
- box cox method

# %%
plt.figure(figsize=(14,4))
plt.subplot(1,2,1).boxplot(visa_df[['prevailing_wage']],vert=False)
plt.subplot(1,2,2).boxplot(transform_wage,vert=False)
plt.show()

# %% [markdown]
# - transformation affect the outlier of data
# - logt ransformation
# - exp transformation
# - reciprocal transformation
# - sqrt transformation
# - power transformation
# - scalling of data
# - z_scale
# - min_max scale
# - so thats why based on problem statement
# - two approches
# - first treat the outliers then do transformation or scaling
# - second transform or scale the data then work on outlier
#     - in this case if u found any outliers,it is called as **influential outliers**
# - we cant say, which is the best method,it completely depends on problem to problem
# -
