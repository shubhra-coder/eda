# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
visa_df=pd.read_csv(r"C:\Users\kisho\Documents\data set\Visadataset.csv")
cat=visa_df.select_dtypes(include="object").columns
num=visa_df.select_dtypes(exclude="object").columns
cat,num
# Out:
# (Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#         'requires_job_training', 'region_of_employment', 'unit_of_wage',
#         'full_time_position', 'case_status'],
#        dtype='object'),
#  Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object'))

# %% [markdown]
# **encoding**
# - it means converting catagoricalcolumn data to numerical data
# - because ml model expect the data should be in numerical format
# - ml models devlop by math algorithm
# - it is very very important to apply encoding
# - the following methods are
# - 1.map
# - 2.np.where
# - 3.one hot encoding
# - 4.lable noder

# %% [markdown]
# **map**
# - it is one method to convert catagorical value to numerical value.
# - take one catagorical column
# - get the unique lables first
# - make a dictionary with assign a no. to each lable
# - for example case status has 2 lables
# - 1.cetified
# - 2.denied
# - assign 0 to certified ,1 to denied
# - cret a dictionary lables as keys,no.asvalues only
# - {certified:0,denied:1}

# %%
#read the column
#get the unique lble
#make  a adictionary
#apply the map

# %%
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
d={'Certified':0,'Denied':1}
visa_df['case_status_new']=visa_df['case_status'].map(d)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
#i want to apply the map method for all catagorical columns
#step_1:we need to get unique lbles
#step_3:we need to get a no.=len unique lables
#step_4:we need to creat a dictionary

# %%
unique_lables=sorted(visa_df['case_status'].unique())
list1=[i for i in range(len(unique_lables))] 
unique_lables,list1
d=dict(zip(unique_lables,list1))
visa_df['case_status']=visa_df['case_status'].map(d)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
for i in cat:
    unique_lables=sorted(visa_df[i].unique())
    list1=[i for i in range(len(unique_lables))]
    d=dict(zip(unique_lables,list1))
    visa_df[i]=visa_df[i].map(d)
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %% [markdown]
# **LableEncoder**
#
# - it is a method to convert cat data to numerical data
# - it is the same way how we did in the above
# - the forloop map method we explored
# - but the lable encoder also do the same
# - it is under **scikit_learn** we usually called sklearn package
# - under sklearn we a class called as preprocessing
# - bcoz,currently we are ding data preprocessing only
# - under preprocessing class we havea method called **LableEncoder**
# - sklearn
# - preprocessing
# - LableEncoder
# - any sklearn package has 3 steps
#   - step_1:read the package
#   - step_2:save the pacage
#   - step_3:apply fit transform data

# %%
#step_1:read the package or load the method
from sklearn.preprocessing import LabelEncoder
#step_2:save the package/call the method
le=LabelEncoder()
#step_3:apply fit transform on data
visa_df['case_status']=le.fit_transform(visa_df['case_status'])
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in cat:
    visa_df[i]=le.fit_transform(visa_df[i])
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %% [markdown]
# **fit and transform**
# - fit means devlop the application
# - transform means process the logic
# - if we observe in map method first wedevloped dictionary logic
# - then we apply that dictionary to columns
# - devloping the dictionary is akind of a fitting
# - apply the dictionary to the olumn means we are traforming the data cat to numerical
# - whenever we are transforming the data then use **fit transform**
# - if we are not changing the data then only **fit**

# %% [markdown]
# **np.where**
# - using np.where also we can change the cat data to numerical
# - but np.where is only for binary condition
# - np.wher is same as if and else
# - if condition is true: will apply true value
# - if condition is false:will apply the false value
# - so np.where use for only binary lables
# - a column should have only two unique lables

# %%
#value==certified replace with 0
#otherwise 1
np.where(con,0,1)

# %%
con=visa_df['case_status']=='Certified'
visa_df['case_status']=np.where(con,0,1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **one hot encoder**
# - one hot means if one will be ON,another will be OFF
# - ON represents with 1
# - OFF represents with 0
# - for example case status has 2 unique lables
# 1.certified
# 2.denied
# - one hot encoder creats new columns which is equal to no.of unique lables
# - for ex.case_status will creat two new extra columns
# - case_status_certified
# - case_status_denied

# %% [markdown]
# - in order to one hot encoder we have a method called
# **pd.get_dummies**

# %% [markdown]
# **pd.get_dummies**

# %%
df=pd.get_dummies(visa_df['case_status'],dtype='int')
df['case_status']=visa_df['case_status'].values
df['dummy']=[i for i in range(len(visa_df))]
df
# Out:
#        Certified  Denied case_status  dummy
# 0              0       1      Denied      0
# 1              1       0   Certified      1
# 2              0       1      Denied      2
# 3              0       1      Denied      3
# 4              1       0   Certified      4
# ...          ...     ...         ...    ...
# 25475          1       0   Certified  25475
# 25476          1       0   Certified  25476
# 25477          1       0   Certified  25477
# 25478          1       0   Certified  25478
# 25479          1       0   Certified  25479
#
# [25480 rows x 4 columns]

# %%
**join 2 data frame**

# %%
df1=pd.get_dummies(visa_df['case_status'],dtype='int')
df1
# Out:
#        Certified  Denied
# 0              0       1
# 1              1       0
# 2              0       1
# 3              0       1
# 4              1       0
# ...          ...     ...
# 25475          1       0
# 25476          1       0
# 25477          1       0
# 25478          1       0
# 25479          1       0
#
# [25480 rows x 2 columns]

# %%
df2=visa_df[['case_status']]
df2
# Out:
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 1 columns]

# %% [markdown]
# **adding the 2 data frame**
# - merge
# - join
# - concat
# - append

# %%
pd.concat([df1,df2],axis=1)
# Out:
#        Certified  Denied case_status
# 0              0       1      Denied
# 1              1       0   Certified
# 2              0       1      Denied
# 3              0       1      Denied
# 4              1       0   Certified
# ...          ...     ...         ...
# 25475          1       0   Certified
# 25476          1       0   Certified
# 25477          1       0   Certified
# 25478          1       0   Certified
# 25479          1       0   Certified
#
# [25480 rows x 3 columns]

# %%
pd.get_dummies(visa_df,dtype="int")
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage  case_id_EZYV01  \
# 0                14513         2007         592.2029               1
# 1                 2412         2002       83425.6500               0
# 2                44444         2008      122996.8600               0
# 3                   98         1897       83434.0300               0
# 4                 1082         2005      149907.3900               0
# ...                ...          ...              ...             ...
# 25475             2601         2008       77092.5700               0
# 25476             3274         2006      279174.7900               0
# 25477             1121         1910      146298.8500               0
# 25478             1918         1887       86154.7700               0
# 25479             3195         1960       70876.9100               0
#
#        case_id_EZYV02  case_id_EZYV03  case_id_EZYV04  case_id_EZYV05  \
# ...

# %%
- in one hot encoder a new column will created
- the new columns equal to no.of unique lables
- because of casse status two extra columns created
- because of continent 6 extra columns are created
- because of case id 25480 unique ids,25480 columns created

# %%
count=0
for i in cat:
    count=count+visa_df[i].nunique()
print(count+len(num))
# Out:
# 25510

# %%
#except case id
count=0
for i in cat[1:]:
    count=count+visa_df[i].nunique()
print(count)
print(count+len(num))
# Out:
# 27
# 30

# %%
for i in cat[1:]:
    print(visa_df[i].unique(),visa_df[i].nunique())
# Out:
# ['Asia' 'Africa' 'North America' 'Europe' 'South America' 'Oceania'] 6
# ['High School' "Master's" "Bachelor's" 'Doctorate'] 4
# ['N' 'Y'] 2
# ['N' 'Y'] 2
# ['West' 'Northeast' 'South' 'Midwest' 'Island'] 5
# ['Hour' 'Year' 'Week' 'Month'] 4
# ['Y' 'N'] 2
# ['Denied' 'Certified'] 2

# %% [markdown]
# **advantages**
#
# - using one hot encoder we will get new columns
# - the new column value at a time only one will be true ,another will be false.
# - which means new columns are independent each other
# - independent means no relation
# - means no **multi colineraity**
# - multi colinearity is animportant property in machine learning
# - **ml models expect the column should be independent each other**
# - so one hot encoder use the nomulticolineartity

# %% [markdown]
# **disadvantages**
# - it will increase many columns
# - inthe aboveex.total column becomes 25510
# - this is happendbecause of case id
# - in realtime we will drop the id columns
# - eventhough if we drop stillwe are getting 30 columns
# - more columns means ,more time to process
# - we required more infrastructure(cpu-gpu-tpu)
# - this is clled as **curse of dimensionality**
